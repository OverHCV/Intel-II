# %% [markdown]
# # Parcial I - Sobre clasificadores

# %% [markdown]
# ## Mínimos Cuadrados
# ## Evaluación estadística

# %% [markdown]
# ## Naive Bayes
# ## Evaluación estadística

# %% [markdown]
# ## K Nearest Neighbours
# ## Evaluación estadística
